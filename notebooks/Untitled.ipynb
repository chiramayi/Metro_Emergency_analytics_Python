# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import datetime as dt

# %%
counties = gpd.read_file('tn_county_lines.csv')

# %%
counties
# Out:
#    OBJECTID STATEFP COUNTYFP  COUNTYNS  GEOID      NAME         NAMELSAD LSAD  \
# 0        30      47      065  01639749  47065  Hamilton  Hamilton County   06
# 1        65      47      115  01639770  47115    Marion    Marion County   06
# 2        68      47      185  01639800  47185     White     White County   06
# 3       129      47      129  01639778  47129    Morgan    Morgan County   06
# 4       182      47      013  01639728  47013  Campbell  Campbell County   06
# ..      ...     ...      ...       ...    ...       ...              ...  ...
# 90     3079      47      039  01639739  47039   Decatur   Decatur County   06
# 91     3084      47      119  01639772  47119     Maury     Maury County   06
# 92     3102      47      047  01639742  47047   Fayette   Fayette County   06
# 93     3107      47      063  01648576  47063   Hamblen   Hamblen County   06
# 94     3189      47      101  01639765  47101     Lewis     Lewis County   06
#
#    CLASSFP  MTFCC  ... CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# 0       H1  G4020  ...  16860                 A  1404654388  86645833
# 1       H1  G4020  ...  16860                 A  1290468301  36484703
# 2       H1  G4020  ...                        A   975592113   7113369
# 3       H1  G4020  ...  28940                 A  1352439680    823018
# 4       H1  G4020  ...  28940                 A  1243615770  46494677
# ..     ...    ...  ...    ...      ...      ...         ...       ...
# 90      H1  G4020  ...                        A   864738982  28503792
# 91      H1  G4020  ...  34980                 A  1588021132   6319196
# 92      H1  G4020  ...  32820                 A  1825359412   3774866
# 93      H1  G4020  ...  34100                 A   417477290  37851130
# 94      H1  G4020  ...                        A   730614735   1024940
#
#        INTPTLAT      INTPTLON      SHAPE_Length          SHAPE_Area geometry
# 0   +35.1634720  -085.2018432  1.98871731200591   0.147573144833735     None
# 1   +35.1334215  -085.6183990   1.6313058231546   0.131228181426278     None
# 2   +35.9270486  -085.4557854  1.87046340954659  0.0981368489552335     None
# 3   +36.1386970  -084.6392616  1.90603202999328   0.135494347799496     None
# 4   +36.4015922  -084.1592495  2.05402999627188   0.129608375402292     None
# ..          ...           ...               ...                 ...      ...
# 90  +35.6031362  -088.1102917  1.66868480689954  0.0888473830205353     None
# 91  +35.6156963  -087.0777632  2.15931787396763   0.158609764186941     None
# 92  +35.1969933  -089.4138027  1.73550766802673   0.181039267604493     None
# 93  +36.2183967  -083.2660711  1.49560903200325  0.0456363142928662     None
# 94  +35.5232441  -087.4969827  1.54081018263764  0.0727056769035294     None
#
# [95 rows x 21 columns]

# %%
counties['geometry'] = counties.apply(lambda x: Polygon((float(x.INTPTLAT), 
                                                         float(x.INTPTLON))), 
                                        axis=1)

counties.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bff375abd40b> in <module>
# ----> 1 counties['geometry'] = counties.apply(lambda x: Polygon((float(x.INTPTLAT),
#       2                                                          float(x.INTPTLON))),
#       3                                         axis=1)
#       4
#       5 counties.head(2)
#
# /opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7550             kwds=kwds,
#    7551         )
# -> 7552         return op.get_result()
#    7553
#    7554     def applymap(self, func) -> "DataFrame":
#
# /opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# /opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# /opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-8-bff375abd40b> in <lambda>(x)
# ----> 1 counties['geometry'] = counties.apply(lambda x: Polygon((float(x.INTPTLAT),
#       2                                                          float(x.INTPTLON))),
#       3                                         axis=1)
#       4
#       5 counties.head(2)
#
# NameError: name 'Polygon' is not defined
